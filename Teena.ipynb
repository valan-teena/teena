# %%
import vega_datasets

# %%
dir(vega_datasets)
# Out:
# ['DataLoader',
#  'LocalDataLoader',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'core',
#  'data',
#  'local_data']

# %%
dir(vega_datasets.data)
# Out:
# ['7zip',
#  'airports',
#  'annual_precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2_concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare_dependencies',
#  'flights_10k',
#  'flights_200k',
#  'flights_20k',
#  'flights_2k',
#  'flights_3m',
#  'flights_5k',
#  'flights_airport',
#  'gapminder',
#  'gapminder_health_income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa_electricity',
#  'iris',
#  'jobs',
#  'la_riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal_2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle_temps',
#  'seattle_weather',
#  'sf_temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
# ...

# %%
import pandas as pd

# %%
df=vega_datasets.data.movies()

# %%
df      #unsupervised
# Out:
#                            Title    US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 0                 The Land Girls    146083.0         146083.0           NaN
# 1         First Love, Last Rites     10876.0          10876.0           NaN
# 2     I Married a Strange Person    203134.0         203134.0           NaN
# 3           Let's Talk About Sex    373615.0         373615.0           NaN
# 4                           Slam   1009819.0        1087521.0           NaN
# ...                          ...         ...              ...           ...
# 3196  Zack and Miri Make a Porno  31452765.0       36851125.0    21240321.0
# 3197                      Zodiac  33080084.0       83080084.0    20983030.0
# 3198                        Zoom  11989328.0       12506188.0     6679409.0
# 3199         The Legend of Zorro  45575336.0      141475336.0           NaN
# 3200           The Mask of Zorro  93828745.0      233700000.0           NaN
#
# ...

# %%
df1=vega_datasets.data.obesity()

# %%
df1      #unsupervised
# Out:
#     id   rate state
# 0    1  0.187    AL
# 1    2  0.198    AK
# 2    4  0.133    AZ
# 3    5  0.175    AR
# 4    6  0.151    CA
# 5    8  0.100    CO
# 6    9  0.125    CT
# 7   10  0.171    DE
# 8   12  0.172    FL
# 9   13  0.133    GA
# 10  15  0.108    HI
# 11  16  0.142    ID
# 12  17  0.167    IL
# 13  18  0.201    IN
# 14  19  0.175    IA
# 15  20  0.159    KS
# 16  21  0.169    KY
# 17  22  0.177    LA
# 18  23  0.141    ME
# 19  24  0.163    MD
# 20  25  0.117    MA
# 21  26  0.182    MI
# 22  27  0.153    MN
# 23  28  0.195    MS
# 24  29  0.189    MO
# 25  30  0.134    MT
# 26  31  0.163    NE
# 27  32  0.133    NV
# 28  33  0.151    NH
# 29  34  0.145    NJ
# 30  35  0.130    NM
# 31  36  0.139    NY
# 32  37  0.169    NC
# 33  38  0.164    ND
# 34  39  0.175    OH
# 35  40  0.135    OK
# 36  41  0.152    OR
# 37  42  0.169    PA
# 38  44  0.132    RI
# 39  45  0.167    SC
# 40  46  0.139    SD
# 41  47  0.184    TN
# 42  48  0.159    TX
# 43  49  0.140    UT
# ...

# %%
df2=vega_datasets.data.monarchs()

# %%
df2     #unsupervised
# Out:
#           name  start   end  index  commonwealth
# 0    Elizabeth   1565  1603      0           NaN
# 1      James I   1603  1625      1           NaN
# 2    Charles I   1625  1649      2           NaN
# 3     Cromwell   1649  1660      3           1.0
# 4   Charles II   1660  1685      4           NaN
# 5     James II   1685  1689      5           NaN
# 6          W&M   1689  1702      6           NaN
# 7         Anne   1702  1714      7           NaN
# 8     George I   1714  1727      8           NaN
# 9    George II   1727  1760      9           NaN
# 10  George III   1760  1820     10           NaN
# 11   George IV   1820  1820     11           NaN

# %%
df3=vega_datasets.data.miserables()

# %%
df3    # unsupervised
# Out:
# (                  name  group
#  index
#  0               Myriel      1
#  1             Napoleon      1
#  2      Mlle.Baptistine      1
#  3         Mme.Magloire      1
#  4         CountessdeLo      1
#  ...                ...    ...
#  72           Toussaint      5
#  73              Child1     10
#  74              Child2     10
#  75              Brujon      4
#  76       Mme.Hucheloup      8
#
#  [77 rows x 2 columns],
#       source  target  value
#  0         1       0      1
#  1         2       0      8
#  2         3       0     10
#  3         3       2      6
#  4         4       0      1
#  ..      ...     ...    ...
#  249      76      66      1
#  250      76      63      1
#  251      76      62      1
#  252      76      48      1
#  253      76      58      1
#
#  [254 rows x 3 columns])

# %%
df4=vega_datasets.data.lookup_people()

# %%
df4     # supervised
# Out:
#      name  age  height
# 0    Alan   25     180
# 1  George   32     174
# 2    Fred   39     182
# 3   Steve   42     161
# 4    Nick   23     180
# 5    Will   21     168
# 6    Cole   51     160
# 7    Rick   63     181
# 8     Tom   54     179

# %%
df5=vega_datasets.data.uniform_2d()

# %%
df5   # unsupervised
# Out:
#             u         v
# 0   -0.219847  0.235878
# 1    0.006570 -0.090268
# 2   -0.102650 -0.475977
# 3    0.033202 -0.255645
# 4   -0.156938  0.123563
# ..        ...       ...
# 495  0.454427 -0.109817
# 496  0.275691 -0.020883
# 497 -0.269289 -0.311689
# 498  0.219226  0.425301
# 499  0.343626  0.321399
#
# [500 rows x 2 columns]

# %%
df6=vega_datasets.data.climate()

# %%
df6   # unsupervised
# Out:
#                STATION                      STATION_NAME  ELEVATION  LATITUDE  \
# 0    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 1    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 2    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 3    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 4    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# ..                 ...                               ...        ...       ...
# 739  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 740  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 741  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 742  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 743  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
#
# ...

# %%
df7=vega_datasets.data.wheat()

# %%
df7   #supervised
# Out:
#     year  wheat  wages
# 0   1565   41.0   5.00
# 1   1570   45.0   5.05
# 2   1575   42.0   5.08
# 3   1580   49.0   5.12
# 4   1585   41.5   5.15
# 5   1590   47.0   5.25
# 6   1595   64.0   5.54
# 7   1600   27.0   5.61
# 8   1605   33.0   5.69
# 9   1610   32.0   5.78
# 10  1615   33.0   5.94
# 11  1620   35.0   6.01
# 12  1625   33.0   6.12
# 13  1630   45.0   6.22
# 14  1635   33.0   6.30
# 15  1640   39.0   6.37
# 16  1645   53.0   6.45
# 17  1650   42.0   6.50
# 18  1655   40.5   6.60
# 19  1660   46.5   6.75
# 20  1665   32.0   6.80
# 21  1670   37.0   6.90
# 22  1675   43.0   7.00
# 23  1680   35.0   7.30
# 24  1685   27.0   7.60
# 25  1690   40.0   8.00
# 26  1695   50.0   8.50
# 27  1700   30.0   9.00
# 28  1705   32.0  10.00
# 29  1710   44.0  11.00
# 30  1715   33.0  11.75
# 31  1720   29.0  12.50
# 32  1725   39.0  13.00
# 33  1730   26.0  13.30
# 34  1735   32.0  13.60
# 35  1740   27.0  14.00
# 36  1745   27.5  14.50
# 37  1750   31.0  15.00
# 38  1755   35.5  15.70
# ...

# %%
df8=vega_datasets.data.seattle_temps()

# %%
df8    # supervised
# Out:
#                     date  temp
# 0    2010-01-01 00:00:00  39.4
# 1    2010-01-01 01:00:00  39.2
# 2    2010-01-01 02:00:00  39.0
# 3    2010-01-01 03:00:00  38.9
# 4    2010-01-01 04:00:00  38.8
# ...                  ...   ...
# 8754 2010-12-31 19:00:00  40.7
# 8755 2010-12-31 20:00:00  40.5
# 8756 2010-12-31 21:00:00  40.2
# 8757 2010-12-31 22:00:00  40.0
# 8758 2010-12-31 23:00:00  39.6
#
# [8759 rows x 2 columns]

# %%
df9=vega_datasets.data.flare()

# %%
df9  # unsupervised
# Out:
#       id                  name  parent     size
# 0      1                 flare     NaN      NaN
# 1      2             analytics     1.0      NaN
# 2      3               cluster     2.0      NaN
# 3      4  AgglomerativeCluster     3.0   3938.0
# 4      5    CommunityStructure     3.0   3812.0
# ..   ...                   ...     ...      ...
# 247  248          OperatorList   211.0   5248.0
# 248  249      OperatorSequence   211.0   4190.0
# 249  250        OperatorSwitch   211.0   2581.0
# 250  251          SortOperator   211.0   2023.0
# 251  252         Visualization   169.0  16540.0
#
# [252 rows x 4 columns]
