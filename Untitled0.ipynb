# %%
import pandas as pd

# %%
df=pd.read_csv("/content/world food production.csv")

# %%
df
# Out:
#             Entity  Year  Maize Production (tonnes)  \
# 0      Afghanistan  1961                   700000.0
# 1      Afghanistan  1962                   700000.0
# 2      Afghanistan  1963                   713000.0
# 3      Afghanistan  1964                   720000.0
# 4      Afghanistan  1965                   720000.0
# ...            ...   ...                        ...
# 11907     Zimbabwe  2017                  1532572.0
# 11908     Zimbabwe  2018                  1560100.0
# 11909     Zimbabwe  2019                   773976.0
# 11910     Zimbabwe  2020                  1202347.0
# 11911     Zimbabwe  2021                  1469664.0
#
#        Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 0                       319000.00               7.467702e+06
# 1                       319000.00               7.420515e+06
# 2                       319000.00               8.479074e+06
# 3                       380000.00               9.113779e+06
# ...

# %%
df1=pd.read_csv("/content/ed_sheeran_spotify.csv")

# %%
df1
# Out:
#      Unnamed: 0                            name                         album  \
# 0             0                             One  x (10th Anniversary Edition)
# 1             1                      I'm a Mess  x (10th Anniversary Edition)
# 2             2                            Sing  x (10th Anniversary Edition)
# 3             3                           Don't  x (10th Anniversary Edition)
# 4             4                            Nina  x (10th Anniversary Edition)
# ..          ...                             ...                           ...
# 268         268                    Give Me Love                             +
# 269         269  Autumn Leaves - Deluxe Edition                             +
# 270         270    Little Bird - Deluxe Edition                             +
# 271         271      Gold Rush - Deluxe Edition                             +
# 272         272        Sunburn - Deluxe Edition                             +
#
# ...

# %%
df2=pd.read_csv("/content/bank.csv")

# %%
df2
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df3=pd.read_csv("/content/train.csv")

# %%
df3
# Out:
#         id  chromogram_0_0  chromogram_0_1  chromogram_0_10  chromogram_0_11  \
# 0        0        0.997944        0.832392         0.765386         0.704275
# 1        1        0.996255        0.839120         0.760417         0.705142
# 2        2        0.970810        0.823540         0.759508         0.709058
# 3        3        1.000000        0.855558         0.752038         0.710977
# 4        4        1.000000        0.884305         0.741885         0.714775
# ...    ...             ...             ...              ...              ...
# 1755  1755        0.005380        0.024429         0.732355         0.356719
# 1756  1756        0.006087        0.023488         0.736068         0.475899
# 1757  1757        0.009701        0.029444         0.732514         0.355017
# 1758  1758        0.005960        0.027000         0.729778         0.407586
# 1759  1759        0.023475        0.027894         0.565448         0.160293
#
# ...

# %%
df4=pd.read_csv("/content/mobile_os_market_share.csv")

# %%
df4
# Out:
#     Year OperatingSystem  Share
# 0   2009             iOS  59.35
# 1   2009         Android   5.58
# 2   2009   BlackBerry OS  14.42
# 3   2009         Windows   2.91
# 4   2009       SymbianOS   2.50
# ..   ...             ...    ...
# 59  2016         Windows   0.91
# 60  2016       SymbianOS   0.01
# 61  2016     Playstation   0.05
# 62  2016           Other   0.25
# 63  2016         Unknown   0.21
#
# [64 rows x 3 columns]

# %%
df5=pd.read_csv("/content/test.csv")

# %%
df5
# Out:
#         id  chromogram_0_0  chromogram_0_1  chromogram_0_10  chromogram_0_11  \
# 0        0        1.000000        0.945011         0.749241         0.714737
# 1        1        0.650246        0.590960         0.712450         0.909643
# 2        2        1.000000        0.833207         0.770394         0.702116
# 3        3        0.991786        0.829836         0.769562         0.702360
# 4        4        0.982724        0.826884         0.768729         0.702757
# ...    ...             ...             ...              ...              ...
# 4276  4276        0.649796        0.736692         1.000000         1.000000
# 4277  4277        0.813268        0.842821         1.000000         1.000000
# 4278  4278        1.000000        1.000000         1.000000         1.000000
# 4279  4279        1.000000        1.000000         1.000000         1.000000
# 4280  4280        1.000000        1.000000         1.000000         1.000000
#
# ...

# %%
df6=pd.read_csv("/content/student_performance_data.csv")

# %%
df6
# Out:
#      StudentID  Gender  Age  StudyHoursPerWeek  AttendanceRate   GPA  \
# 0            1    Male   24                 37           90.75  3.47
# 1            2  Female   22                 37           74.90  2.32
# 2            3    Male   22                 10           53.36  2.38
# 3            4    Male   24                 10           70.26  3.46
# 4            5    Male   18                 19           74.87  2.31
# ..         ...     ...  ...                ...             ...   ...
# 495        496    Male   22                 37           76.61  2.97
# 496        497    Male   23                 11           56.29  3.20
# 497        498  Female   20                  6           56.64  3.20
# 498        499    Male   22                 18           57.18  2.05
# 499        500  Female   24                 21           96.99  2.64
#
#            Major PartTimeJob ExtraCurricularActivities
# 0           Arts         Yes                        No
# ...

# %%
df7=pd.read_csv("/content/ecommerce_clickstream_transactions.csv")

# %%
df7
# Out:
#        UserID  SessionID                   Timestamp     EventType  ProductID  \
# 0           1          1  2024-07-07 18:00:26.959902     page_view        NaN
# 1           1          1  2024-03-05 22:01:00.072000     page_view        NaN
# 2           1          1  2024-03-23 22:08:10.568453  product_view  prod_8199
# 3           1          1  2024-03-12 00:32:05.495638   add_to_cart  prod_4112
# 4           1          1  2024-02-25 22:43:01.318876   add_to_cart  prod_3354
# ...       ...        ...                         ...           ...        ...
# 74812    1000         10  2024-05-11 22:48:45.500117      purchase  prod_1238
# 74813    1000         10  2024-03-29 04:09:32.514318        logout        NaN
# 74814    1000         10  2024-02-09 02:58:56.128697         login        NaN
# 74815    1000         10  2024-04-30 16:19:48.002633      purchase  prod_2515
# 74816    1000         10  2024-04-01 02:19:29.148727        logout        NaN
#
#            Amount   Outcome
# ...

# %%
df8=pd.read_csv("/content/MA_Public_Schools_2017.csv")

# %%
df8
# Out:
#       School Code                                        School Name  \
# 0           10505                                      Abington High
# 1           10003                     Beaver Brook Elementary School
# 2           10002                           Center Elementary School
# 3           10405                               Frolio Middle School
# 4           10015                        Woodsdale Elementary School
# ...           ...                                                ...
# 1856     35060505     Pioneer Charter School of Science II (PCSS-II)
# 1857     35100205             Springfield Preparatory Charter School
# 1858     39020900  TEC Connections Academy Commonwealth Virtual S...
# 1859     35050405            UP Academy Charter School of Dorchester
# 1860     35120305           UP Academy Charter School of Springfield
#
#          School Type   Function          Contact Name  \
# 0      Public School  Principal  Teresa Sullivan-Cruz
# ...

# %%
df9=pd.read_csv("/content/Australian Vehicle Prices.csv")

# %%
df9
# Out:
#                Brand    Year    Model               Car/Suv  \
# 0          Ssangyong  2022.0   Rexton  Sutherland Isuzu Ute
# 1                 MG  2022.0      MG3             Hatchback
# 2                BMW  2022.0     430I                 Coupe
# 3      Mercedes-Benz  2011.0     E500                 Coupe
# 4            Renault  2022.0   Arkana                   SUV
# ...              ...     ...      ...                   ...
# 16729         Toyota  2014.0  Alphard              SYC Cars
# 16730  Mercedes-Benz  2012.0  S-Class        USED Dealer ad
# 16731         Suzuki  2022.0   Vitara   Bremer Suzuki - New
# 16732  Mercedes-Benz  2016.0   GLC250                   SUV
# 16733  Mercedes-Benz  2021.0     C200                 Sedan
#
#                                            Title UsedOrNew Transmission  \
# 0           2022 Ssangyong Rexton Ultimate (awd)      DEMO    Automatic
# 1      2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# ...
